# %%
import time
import numpy as np
from gep_config_parser import *
from data_wrangling import dataframe_to_dict
import pyomo.environ as pyo

from gep_main import run_model, prep_data
from gep_problem import GEPProblem

import torch

DTYPE = torch.float64

torch.set_default_dtype(DTYPE)

# DEVICE = (
#     torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
# )

DEVICE = "cpu"

# %%
CONFIG_FILE_NAME        = "config.toml"
VISUALIZATION_FILE_NAME = "visualization.toml"

HIGHS  = "HiGHS"
GUROBI = "Gurobi"

SAMPLE_DURATION = 12 # 12 hours

## Step 0: Activate environment - ensure consistency accross computers
# print("Reading the data")
# print("Activating the environment")

# %%
## Step 1: parse the input data
print("Parsing the config file")

data = parse_config(CONFIG_FILE_NAME)
experiment = data["experiment"]
outputs_config = data["outputs_config"]

print("Initializing the solver")
optimizer_name = data["optimizer_config"]["solver"]

# Determine the optimizer
if optimizer_name == HIGHS:
    raise NotImplementedError(f"{optimizer_name}: Not implemented")
elif optimizer_name == GUROBI:
    
    print(f"Using {GUROBI}")
    optimizer = "gurobi_direct"
else:
    raise ValueError(f"{optimizer_name}: Not implemented")
# Out:
# Parsing the config file
# Initializing the solver
# Using Gurobi

# %%
for i, experiment_instance in enumerate(experiment["experiments"]):
    # Setup output dataframe
    df_res = pd.DataFrame(columns=["setup_time", "presolve_time", "barrier_time", "crossover_time", "restore_time", "objective_value"])

    T, N, G, L, pDemand, pGenAva, pVOLL, pWeight, pRamping, pInvCost, pVarCost, pUnitCap, pExpCap, pImpCap = prep_data(experiment_instance)

    T_ranges = [range(i, i + SAMPLE_DURATION, 1) for i in range(1, len(T), SAMPLE_DURATION)]
    objective_values = []
    times = []
    for t in T_ranges[:1]:
        # Run one experiment for j repeats
        model, solver, time_taken = run_model(experiment_instance, t, N, G, L, pDemand, pGenAva, pVOLL, pWeight, pRamping, pInvCost, pVarCost, pUnitCap, pExpCap, pImpCap)
        
        # print("Print values for all variables")
        # for v in model.component_data_objects(pyo.Var):
        #     print(str(v), v.value)

        objective_values.append(model.obj())
        times.append(time_taken)

    # Write the number to the file
    # file_path = os.path.join("outputs/Gurobi", f"samplesize_{str(SAMPLE_DURATION)}_node_{len(N)}_gen_{len(G)}_lines_{len(L)}.txt")
    # with open(file_path, "w") as file:
    #     file.write(f"N: {str(N)}\n")
    #     file.write(f"G: {str(G)}\n")
    #     file.write(f"L: {str(L)}\n")
    #     file.write(f"Obj value mean: {str(np.mean(objective_values))}\n")
    #     file.write(f"Time taken mean: {str(np.mean(times))}\n")
# Out:
# Wrangling the input data
# Populating the model
# Adding model variables
# Formulating the objective
# Adding model constraints
# Solving the optimization problem
# Set parameter OutputFlag to value 1
# Set parameter Method to value 2
# Set parameter OutputFlag to value 1
# Set parameter LogFile to value "outputs/Gurobi/output.txt"
# Set parameter Crossover to value 0
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 22.3.0 22D49)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Non-default parameters:
# Method  2
# Crossover  0
#
# Optimize a model with 140 rows, 113 columns and 467 nonzeros
# Model fingerprint: 0x93c00021
# Coefficient statistics:
#   Matrix range     [7e-02, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [2e+03, 3e+04]
#   RHS range        [4e+03, 3e+04]
# Presolve removed 126 rows and 104 columns
# Presolve time: 0.00s
# Presolved: 14 rows, 9 columns, 42 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.900e+01
#  Factor NZ  : 1.050e+02
#  Factor Ops : 1.015e+03 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.13919896e+08  8.11280905e+08  1.03e+03 1.66e+02  1.92e+06     0s
#    1   8.16920646e+08  8.13794391e+08  2.99e+02 1.58e+02  4.40e+05     0s
#    2   8.20036143e+08  8.16051609e+08  1.24e-11 9.73e-14  1.73e+05     0s
#    3   8.18705590e+08  8.18338774e+08  3.30e-12 2.27e-13  1.59e+04     0s
#    4   8.18649113e+08  8.18647717e+08  2.27e-12 8.88e-16  6.07e+01     0s
#    5   8.18648033e+08  8.18648032e+08  2.05e-12 2.27e-13  6.07e-02     0s
#    6   8.18648032e+08  8.18648032e+08  6.42e-12 0.00e+00  6.07e-05     0s
#    7   8.18648032e+08  8.18648032e+08  9.09e-13 1.14e-13  6.07e-08     0s
#    8   8.18648032e+08  8.18648032e+08  4.43e-13 9.09e-13  6.07e-11     0s
#
# Barrier solved model in 8 iterations and 0.01 seconds (0.00 work units)
# Optimal objective 8.18648032e+08
#
# Objective Value: 818648032.282804

# %%
for var in model.component_objects(pyo.Var, active=True):
        for index in var:
            print(f"{var.name}[{index}] = {var[index].value}")
# Out:
# vInvCost[None] = 30091210.065572247
# vOpeCost[None] = 788556822.2172318
# vGenInv[('BEL', 'SunPV')] = 3188.980650317394
# vGenInv[('GER', 'SunPV')] = 15130.885774262544
# vGenInv[('NED', 'SunPV')] = 6756.141963396936
# vGenProd[('BEL', 'SunPV', 1)] = 0.0
# vGenProd[('BEL', 'SunPV', 2)] = 0.0
# vGenProd[('BEL', 'SunPV', 3)] = 0.0
# vGenProd[('BEL', 'SunPV', 4)] = 0.0
# vGenProd[('BEL', 'SunPV', 5)] = 0.0
# vGenProd[('BEL', 'SunPV', 6)] = 0.0
# vGenProd[('BEL', 'SunPV', 7)] = 0.0
# vGenProd[('BEL', 'SunPV', 8)] = 0.0
# vGenProd[('BEL', 'SunPV', 9)] = 3986.225812896743
# vGenProd[('BEL', 'SunPV', 10)] = 3646.9423378464453
# vGenProd[('BEL', 'SunPV', 11)] = 3942.8316931533423
# vGenProd[('BEL', 'SunPV', 12)] = 4305.202009367987
# vGenProd[('GER', 'SunPV', 1)] = 0.0
# vGenProd[('GER', 'SunPV', 2)] = 0.0
# vGenProd[('GER', 'SunPV', 3)] = 0.0
# vGenProd[('GER', 'SunPV', 4)] = 0.0
# vGenProd[('GER', 'SunPV', 5)] = 0.0
# vGenProd[('GER', 'SunPV', 6)] = 0.0
# vGenProd[('GER', 'SunPV', 7)] = 0.0
# vGenProd[('GER', 'SunPV', 8)] = 0.0
# vGenProd[('GER', 'SunPV', 9)] = 33287.948703377595
# vGenProd[('GER', 'SunPV', 10)] = 25726.0943496955
# vGenProd[('GER', 'SunPV', 11)] = 28548.186786092498
# vGenProd[('GER', 'SunPV', 12)] = 31825.768293239198
# vGenProd[('NED', 'SunPV', 1)] = 0.0
# vGenProd[('NED', 'SunPV', 2)] = 0.0
# vGenProd[('NED', 'SunPV', 3)] = 0.0
# vGenProd[('NED', 'SunPV', 4)] = 0.0
# vGenProd[('NED', 'SunPV', 5)] = 0.0
# vGenProd[('NED', 'SunPV', 6)] = 0.0
# vGenProd[('NED', 'SunPV', 7)] = 0.0
# vGenProd[('NED', 'SunPV', 8)] = 0.0
# vGenProd[('NED', 'SunPV', 9)] = 5067.106472547701
# vGenProd[('NED', 'SunPV', 10)] = 15841.594534633205
# vGenProd[('NED', 'SunPV', 11)] = 16309.891277784558
# vGenProd[('NED', 'SunPV', 12)] = 16664.059339737953
# vLineFlow[('BEL', 'GER', 1)] = -2000.0
# vLineFlow[('BEL', 'GER', 2)] = -2000.0
# vLineFlow[('BEL', 'GER', 3)] = -2000.0
# vLineFlow[('BEL', 'GER', 4)] = -2000.0
# vLineFlow[('BEL', 'GER', 5)] = -2000.0
# vLineFlow[('BEL', 'GER', 6)] = -2000.0
# vLineFlow[('BEL', 'GER', 7)] = -2000.0
# vLineFlow[('BEL', 'GER', 8)] = -2000.0
# vLineFlow[('BEL', 'GER', 9)] = -1999.9999999999977
# vLineFlow[('BEL', 'GER', 10)] = -2000.0
# vLineFlow[('BEL', 'GER', 11)] = -2000.0
# vLineFlow[('BEL', 'GER', 12)] = -2000.0
# vLineFlow[('BEL', 'NED', 1)] = 2000.0
# vLineFlow[('BEL', 'NED', 2)] = 2000.0
# vLineFlow[('BEL', 'NED', 3)] = 2000.0
# vLineFlow[('BEL', 'NED', 4)] = 2000.0
# vLineFlow[('BEL', 'NED', 5)] = 2000.0
# vLineFlow[('BEL', 'NED', 6)] = 2000.0
# vLineFlow[('BEL', 'NED', 7)] = 2000.0
# vLineFlow[('BEL', 'NED', 8)] = 2000.0
# vLineFlow[('BEL', 'NED', 9)] = 2400.0
# vLineFlow[('BEL', 'NED', 10)] = 1971.5428697848956
# vLineFlow[('BEL', 'NED', 11)] = 2040.0884009353422
# vLineFlow[('BEL', 'NED', 12)] = 2153.5564269097467
# vLineFlow[('GER', 'NED', 1)] = -2000.0
# vLineFlow[('GER', 'NED', 2)] = -2000.0
# vLineFlow[('GER', 'NED', 3)] = -2000.0
# vLineFlow[('GER', 'NED', 4)] = -2000.0
# vLineFlow[('GER', 'NED', 5)] = -2000.0
# vLineFlow[('GER', 'NED', 6)] = -2000.0
# vLineFlow[('GER', 'NED', 7)] = -2000.0
# vLineFlow[('GER', 'NED', 8)] = -2000.0
# vLineFlow[('GER', 'NED', 9)] = 5000.0
# vLineFlow[('GER', 'NED', 10)] = -5000.0
# vLineFlow[('GER', 'NED', 11)] = -5000.0
# vLineFlow[('GER', 'NED', 12)] = -5000.0
# vLossLoad[('BEL', 1)] = 5336.38128679075
# vLossLoad[('BEL', 2)] = 4884.63342930747
# vLossLoad[('BEL', 3)] = 4489.7215278633
# vLossLoad[('BEL', 4)] = 4159.48502467053
# vLossLoad[('BEL', 5)] = 3890.98412889956
# vLossLoad[('BEL', 6)] = 3778.29214709788
# vLossLoad[('BEL', 7)] = 3817.48935815933
# vLossLoad[('BEL', 8)] = 3566.62720736601
# vLossLoad[('BEL', 9)] = 0.0
# vLossLoad[('BEL', 10)] = 0.0
# vLossLoad[('BEL', 11)] = 0.0
# vLossLoad[('BEL', 12)] = 0.0
# vLossLoad[('GER', 1)] = 33061.6700767249
# vLossLoad[('GER', 2)] = 31449.1851339137
# vLossLoad[('GER', 3)] = 29727.8245842648
# vLossLoad[('GER', 4)] = 28264.6022125711
# vLossLoad[('GER', 5)] = 27576.0331088242
# vLossLoad[('GER', 6)] = 26813.5103930637
# vLossLoad[('GER', 7)] = 25294.1989794578
# vLossLoad[('GER', 8)] = 25573.2654704203
# vLossLoad[('GER', 9)] = 0.0
# vLossLoad[('GER', 10)] = 0.0
# vLossLoad[('GER', 11)] = 0.0
# vLossLoad[('GER', 12)] = 0.0
# vLossLoad[('NED', 1)] = 13170.0435941473
# vLossLoad[('NED', 2)] = 12924.855962422
# vLossLoad[('NED', 3)] = 12508.6301843722
# vLossLoad[('NED', 4)] = 12069.6652307994
# vLossLoad[('NED', 5)] = 11799.7611039405
# vLossLoad[('NED', 6)] = 11781.9652274443
# vLossLoad[('NED', 7)] = 11915.4343011657
# vLossLoad[('NED', 8)] = 12211.0435829636
# vLossLoad[('NED', 9)] = 0.0
# vLossLoad[('NED', 10)] = 0.0
# vLossLoad[('NED', 11)] = 0.0
# vLossLoad[('NED', 12)] = 0.0

# %%
print("Constraint values:")
for con in model.component_objects(pyo.Constraint, active=True):
    for index in con:
        constraint_expr = con[index].body
        constraint_lb = con[index].lower
        constraint_ub = con[index].upper
        constraint_value = pyo.value(constraint_expr)  # Evaluate the constraint body
        print(f"{con.name}[{index}]:")
        print(f"  Expression Value: {constraint_value}")
        if constraint_lb is not None:
            print(f"  Lower Bound: {constraint_lb}, Feasibility: {constraint_value >= constraint_lb}")
        if constraint_ub is not None:
            print(f"  Upper Bound: {constraint_ub}, Feasibility: {constraint_value <= constraint_ub}")
# Out:
# Constraint values:
# eInvCost[None]:
#   Expression Value: 0.0
#   Lower Bound: 0.0, Feasibility: True
#   Upper Bound: 0.0, Feasibility: True
# eOpeCost[None]:
#   Expression Value: 0.0
#   Lower Bound: 0.0, Feasibility: True
#   Upper Bound: 0.0, Feasibility: True
# eNodeBal[('BEL', 1)]:
#   Expression Value: 5336.38128679075
#   Lower Bound: 5336.38128679075, Feasibility: True
#   Upper Bound: 5336.38128679075, Feasibility: True
# eNodeBal[('BEL', 2)]:
#   Expression Value: 4884.63342930747
#   Lower Bound: 4884.63342930747, Feasibility: True
#   Upper Bound: 4884.63342930747, Feasibility: True
# eNodeBal[('BEL', 3)]:
#   Expression Value: 4489.7215278633
#   Lower Bound: 4489.7215278633, Feasibility: True
#   Upper Bound: 4489.7215278633, Feasibility: True
# eNodeBal[('BEL', 4)]:
#   Expression Value: 4159.48502467053
#   Lower Bound: 4159.48502467053, Feasibility: True
#   Upper Bound: 4159.48502467053, Feasibility: True
# eNodeBal[('BEL', 5)]:
#   Expression Value: 3890.98412889956
#   Lower Bound: 3890.98412889956, Feasibility: True
#   Upper Bound: 3890.98412889956, Feasibility: True
# eNodeBal[('BEL', 6)]:
#   Expression Value: 3778.29214709788
#   Lower Bound: 3778.29214709788, Feasibility: True
#   Upper Bound: 3778.29214709788, Feasibility: True
# eNodeBal[('BEL', 7)]:
#   Expression Value: 3817.48935815933
#   Lower Bound: 3817.48935815933, Feasibility: True
#   Upper Bound: 3817.48935815933, Feasibility: True
# eNodeBal[('BEL', 8)]:
#   Expression Value: 3566.62720736601
#   Lower Bound: 3566.62720736601, Feasibility: True
#   Upper Bound: 3566.62720736601, Feasibility: True
# eNodeBal[('BEL', 9)]:
#   Expression Value: 3586.2258128967405
#   Lower Bound: 3586.22581289674, Feasibility: True
#   Upper Bound: 3586.22581289674, Feasibility: False
# eNodeBal[('BEL', 10)]:
#   Expression Value: 3675.3994680615497
#   Lower Bound: 3675.39946806155, Feasibility: False
#   Upper Bound: 3675.39946806155, Feasibility: True
# eNodeBal[('BEL', 11)]:
#   Expression Value: 3902.743292218
#   Lower Bound: 3902.743292218, Feasibility: True
#   Upper Bound: 3902.743292218, Feasibility: True
# eNodeBal[('BEL', 12)]:
#   Expression Value: 4151.64558245824
#   Lower Bound: 4151.64558245824, Feasibility: True
#   Upper Bound: 4151.64558245824, Feasibility: True
# eNodeBal[('GER', 1)]:
#   Expression Value: 33061.6700767249
#   Lower Bound: 33061.6700767249, Feasibility: True
#   Upper Bound: 33061.6700767249, Feasibility: True
# eNodeBal[('GER', 2)]:
#   Expression Value: 31449.1851339137
#   Lower Bound: 31449.1851339137, Feasibility: True
#   Upper Bound: 31449.1851339137, Feasibility: True
# eNodeBal[('GER', 3)]:
#   Expression Value: 29727.8245842648
#   Lower Bound: 29727.8245842648, Feasibility: True
#   Upper Bound: 29727.8245842648, Feasibility: True
# eNodeBal[('GER', 4)]:
#   Expression Value: 28264.6022125711
#   Lower Bound: 28264.6022125711, Feasibility: True
#   Upper Bound: 28264.6022125711, Feasibility: True
# eNodeBal[('GER', 5)]:
#   Expression Value: 27576.0331088242
#   Lower Bound: 27576.0331088242, Feasibility: True
#   Upper Bound: 27576.0331088242, Feasibility: True
# eNodeBal[('GER', 6)]:
#   Expression Value: 26813.5103930637
#   Lower Bound: 26813.5103930637, Feasibility: True
#   Upper Bound: 26813.5103930637, Feasibility: True
# eNodeBal[('GER', 7)]:
#   Expression Value: 25294.1989794578
#   Lower Bound: 25294.1989794578, Feasibility: True
#   Upper Bound: 25294.1989794578, Feasibility: True
# eNodeBal[('GER', 8)]:
#   Expression Value: 25573.2654704203
#   Lower Bound: 25573.2654704203, Feasibility: True
#   Upper Bound: 25573.2654704203, Feasibility: True
# eNodeBal[('GER', 9)]:
#   Expression Value: 26287.9487033776
#   Lower Bound: 26287.9487033776, Feasibility: True
#   Upper Bound: 26287.9487033776, Feasibility: True
# eNodeBal[('GER', 10)]:
#   Expression Value: 28726.0943496955
#   Lower Bound: 28726.0943496955, Feasibility: True
#   Upper Bound: 28726.0943496955, Feasibility: True
# eNodeBal[('GER', 11)]:
#   Expression Value: 31548.186786092498
#   Lower Bound: 31548.1867860925, Feasibility: False
#   Upper Bound: 31548.1867860925, Feasibility: True
# eNodeBal[('GER', 12)]:
#   Expression Value: 34825.7682932392
#   Lower Bound: 34825.7682932392, Feasibility: True
#   Upper Bound: 34825.7682932392, Feasibility: True
# eNodeBal[('NED', 1)]:
#   Expression Value: 13170.0435941473
#   Lower Bound: 13170.0435941473, Feasibility: True
#   Upper Bound: 13170.0435941473, Feasibility: True
# eNodeBal[('NED', 2)]:
#   Expression Value: 12924.855962422
#   Lower Bound: 12924.855962422, Feasibility: True
#   Upper Bound: 12924.855962422, Feasibility: True
# eNodeBal[('NED', 3)]:
#   Expression Value: 12508.6301843722
#   Lower Bound: 12508.6301843722, Feasibility: True
#   Upper Bound: 12508.6301843722, Feasibility: True
# eNodeBal[('NED', 4)]:
#   Expression Value: 12069.6652307994
#   Lower Bound: 12069.6652307994, Feasibility: True
#   Upper Bound: 12069.6652307994, Feasibility: True
# eNodeBal[('NED', 5)]:
#   Expression Value: 11799.7611039405
#   Lower Bound: 11799.7611039405, Feasibility: True
#   Upper Bound: 11799.7611039405, Feasibility: True
# eNodeBal[('NED', 6)]:
#   Expression Value: 11781.9652274443
#   Lower Bound: 11781.9652274443, Feasibility: True
#   Upper Bound: 11781.9652274443, Feasibility: True
# eNodeBal[('NED', 7)]:
#   Expression Value: 11915.4343011657
#   Lower Bound: 11915.4343011657, Feasibility: True
#   Upper Bound: 11915.4343011657, Feasibility: True
# eNodeBal[('NED', 8)]:
#   Expression Value: 12211.0435829636
#   Lower Bound: 12211.0435829636, Feasibility: True
#   Upper Bound: 12211.0435829636, Feasibility: True
# eNodeBal[('NED', 9)]:
#   Expression Value: 12467.1064725477
#   Lower Bound: 12467.1064725477, Feasibility: True
#   Upper Bound: 12467.1064725477, Feasibility: True
# eNodeBal[('NED', 10)]:
#   Expression Value: 12813.1374044181
#   Lower Bound: 12813.1374044181, Feasibility: True
#   Upper Bound: 12813.1374044181, Feasibility: True
# eNodeBal[('NED', 11)]:
#   Expression Value: 13349.979678719901
#   Lower Bound: 13349.9796787199, Feasibility: True
#   Upper Bound: 13349.9796787199, Feasibility: False
# eNodeBal[('NED', 12)]:
#   Expression Value: 13817.6157666477
#   Lower Bound: 13817.6157666477, Feasibility: True
#   Upper Bound: 13817.6157666477, Feasibility: True
# eMaxProd[('BEL', 'SunPV', 1)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('BEL', 'SunPV', 2)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('BEL', 'SunPV', 3)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('BEL', 'SunPV', 4)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('BEL', 'SunPV', 5)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('BEL', 'SunPV', 6)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('BEL', 'SunPV', 7)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('BEL', 'SunPV', 8)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('BEL', 'SunPV', 9)]:
#   Expression Value: 4.547473508864641e-13
#   Upper Bound: 0.0, Feasibility: False
# eMaxProd[('BEL', 'SunPV', 10)]:
#   Expression Value: -24734.98544997836
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('BEL', 'SunPV', 11)]:
#   Expression Value: -38630.059988583875
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('BEL', 'SunPV', 12)]:
#   Expression Value: -53255.89872886098
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 1)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 2)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 3)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 4)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 5)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 6)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 7)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 8)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 9)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 10)]:
#   Expression Value: -69598.48602815853
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 11)]:
#   Expression Value: -103847.06373870478
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('GER', 'SunPV', 12)]:
#   Expression Value: -124022.35518166499
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 1)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 2)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 3)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 4)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 5)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 6)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 7)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 8)]:
#   Expression Value: 0.0
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 9)]:
#   Expression Value: -1.8189894035458565e-12
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 10)]:
#   Expression Value: -29424.556620126266
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 11)]:
#   Expression Value: -45846.614785467245
#   Upper Bound: 0.0, Feasibility: True
# eMaxProd[('NED', 'SunPV', 12)]:
#   Expression Value: -46168.06091985355
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('BEL', 'SunPV', 2)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('BEL', 'SunPV', 3)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('BEL', 'SunPV', 4)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('BEL', 'SunPV', 5)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('BEL', 'SunPV', 6)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('BEL', 'SunPV', 7)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('BEL', 'SunPV', 8)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('BEL', 'SunPV', 9)]:
#   Expression Value: -27903.580690277195
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('BEL', 'SunPV', 10)]:
#   Expression Value: -32229.089978224238
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('BEL', 'SunPV', 11)]:
#   Expression Value: -31593.917147867043
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('BEL', 'SunPV', 12)]:
#   Expression Value: -31527.436186959294
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('GER', 'SunPV', 2)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('GER', 'SunPV', 3)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('GER', 'SunPV', 4)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('GER', 'SunPV', 5)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('GER', 'SunPV', 6)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('GER', 'SunPV', 7)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('GER', 'SunPV', 8)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('GER', 'SunPV', 9)]:
#   Expression Value: -118020.90903924784
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('GER', 'SunPV', 10)]:
#   Expression Value: -158870.71209630754
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('GER', 'SunPV', 11)]:
#   Expression Value: -148486.76530622842
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('GER', 'SunPV', 12)]:
#   Expression Value: -148031.27623547873
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('NED', 'SunPV', 2)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('NED', 'SunPV', 3)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('NED', 'SunPV', 4)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('NED', 'SunPV', 5)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('NED', 'SunPV', 6)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('NED', 'SunPV', 7)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('NED', 'SunPV', 8)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('NED', 'SunPV', 9)]:
#   Expression Value: -62494.313161421655
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('NED', 'SunPV', 10)]:
#   Expression Value: -56786.931571883855
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('NED', 'SunPV', 11)]:
#   Expression Value: -67093.122890818
#   Upper Bound: 0.0, Feasibility: True
# eRampingUp[('NED', 'SunPV', 12)]:
#   Expression Value: -67207.25157201596
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('BEL', 'SunPV', 2)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('BEL', 'SunPV', 3)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('BEL', 'SunPV', 4)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('BEL', 'SunPV', 5)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('BEL', 'SunPV', 6)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('BEL', 'SunPV', 7)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('BEL', 'SunPV', 8)]:
#   Expression Value: -31889.80650317394
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('BEL', 'SunPV', 9)]:
#   Expression Value: -35876.03231607068
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('BEL', 'SunPV', 10)]:
#   Expression Value: -31550.52302812364
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('BEL', 'SunPV', 11)]:
#   Expression Value: -32185.695858480834
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('BEL', 'SunPV', 12)]:
#   Expression Value: -32252.176819388584
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('GER', 'SunPV', 2)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('GER', 'SunPV', 3)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('GER', 'SunPV', 4)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('GER', 'SunPV', 5)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('GER', 'SunPV', 6)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('GER', 'SunPV', 7)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('GER', 'SunPV', 8)]:
#   Expression Value: -151308.85774262543
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('GER', 'SunPV', 9)]:
#   Expression Value: -184596.80644600303
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('GER', 'SunPV', 10)]:
#   Expression Value: -143747.00338894333
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('GER', 'SunPV', 11)]:
#   Expression Value: -154130.95017902245
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('GER', 'SunPV', 12)]:
#   Expression Value: -154586.43924977214
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('NED', 'SunPV', 2)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('NED', 'SunPV', 3)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('NED', 'SunPV', 4)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('NED', 'SunPV', 5)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('NED', 'SunPV', 6)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('NED', 'SunPV', 7)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('NED', 'SunPV', 8)]:
#   Expression Value: -67561.41963396936
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('NED', 'SunPV', 9)]:
#   Expression Value: -72628.52610651706
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('NED', 'SunPV', 10)]:
#   Expression Value: -78335.90769605487
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('NED', 'SunPV', 11)]:
#   Expression Value: -68029.71637712071
#   Upper Bound: 0.0, Feasibility: True
# eRampingDown[('NED', 'SunPV', 12)]:
#   Expression Value: -67915.58769592276
#   Upper Bound: 0.0, Feasibility: True

# %%
def get_variable_values_as_list(var):
    # Check if the variable is indexed
    if var.is_indexed():
        return [var[idx].value for idx in var]
    else:
        # For scalar variables
        return [var.value]

# Function to get constraint values as a list
def get_constraint_values_as_list(constraint):
    constraint_values = []
    for idx in constraint:
        # Evaluate the constraint body
        constraint_expr_value = pyo.value(constraint[idx].body)
        constraint_values.append(constraint_expr_value)
    return constraint_values

def get_variable_bounds(var):
    lower_bounds = []
    upper_bounds = []
    
    # Check if the variable is indexed
    if var.is_indexed():
        # Iterate through the indices of the variable
        for idx in var:
            lower_bounds.append(var[idx].lb)  # Get lower bound for each index
            upper_bounds.append(var[idx].ub)  # Get upper bound for each index
    else:
        # For scalar variables
        lower_bounds.append(var.lb)  # Get lower bound of scalar variable
        upper_bounds.append(var.ub)  # Get upper bound of scalar variable

    return lower_bounds, upper_bounds

# %% [markdown]
# # !!!!
# ### When using MPS, calculations are done in float32. This introduces errors of the order e-3.

# %%
#T, N, G, L, pDemand, pGenAva, pVOLL, pWeight, pRamping, pInvCost, pVarCost, pUnitCap, pExpCap, pImpCap
data = GEPProblem(T, G, L, N, pDemand, pGenAva, pVOLL, pWeight, pRamping, pInvCost, pVarCost, pUnitCap, pExpCap, pImpCap)

# X contains [pGenAva, pDemand]
X = data.trainX[:1]
# Y contains [*vGenProd, *vLineFlow, *vLossLoad, *vGenInv]

# Y = [model.vGenProd, model.vLineFlow, model.vLossLoad, model.vGenInv]
Y = torch.tensor([[*get_variable_values_as_list(model.vGenProd), \
     *get_variable_values_as_list(model.vLineFlow),
     *get_variable_values_as_list(model.vLossLoad), 
     *get_variable_values_as_list(model.vGenInv)]], device=DEVICE)

g = data.g(X, Y).squeeze(0).tolist()
# Out:
# Size of train set: 584
# Size of val set: 73
# Size of mu: 285
# Size of lambda: 36
# Number of variables (size of y): 111
# Number of inputs (size of X): 72

# %%
print("### Testing constistency of g_x(y) ###")

# g returns: [eMaxProd, eLineFlow, eRampingDown, eRampingUp, eGenProdPositive, eMissedDemandPositive, eNumPowerGenerationUnitsPositive]
print("Testing consistency of eMaxProd")
eMaxProd_idx = len(G) * 12
eMaxProd_PDL = g[:eMaxProd_idx]
eMaxProd_LP = get_constraint_values_as_list(model.eMaxProd)
assert(eMaxProd_PDL == eMaxProd_LP)

print("Testing consistency of eLineFlow")
# Compute indices for slicing
eLineFlow_idx_lb = eMaxProd_idx + len(L) * 12
eLineFlow_idx_ub = eLineFlow_idx_lb + len(L) * 12

# Extract values using the indices
eLineFlow_PDL_lb = np.array(g[eMaxProd_idx:eLineFlow_idx_lb], dtype=np.float64)
eLineFlow_PDL_ub = np.array(g[eLineFlow_idx_lb:eLineFlow_idx_ub], dtype=np.float64)

# Get bounds and variable values as numpy arrays in float64
eLineFlow_LP_lb, eLineFlow_LP_ub = (
    np.array(get_variable_bounds(model.vLineFlow)[0], dtype=np.float64),  # Lower bounds
    np.array(get_variable_bounds(model.vLineFlow)[1], dtype=np.float64),  # Upper bounds
)
vLineFlow = np.array(get_variable_values_as_list(model.vLineFlow), dtype=np.float64)

# Assertions tolerate errors due to floating point precision
assert np.allclose(eLineFlow_PDL_lb + vLineFlow, eLineFlow_LP_lb, atol=1e-10), (
    f"Assertion failed: eLineFlow_PDL_lb + vLineFlow != eLineFlow_LP_lb\n"
    f"  eLineFlow_PDL_lb + vLineFlow = {(eLineFlow_PDL_lb + vLineFlow).tolist()}\n"
    f"  eLineFlow_LP_lb = {eLineFlow_LP_lb.tolist()}"
)
assert np.allclose(-1 * (eLineFlow_PDL_ub - vLineFlow), eLineFlow_LP_ub, atol=1e-10), (
    f"Assertion failed: -1 * (eLineFlow_PDL_ub - vLineFlow) != eLineFlow_LP_ub\n"
    f"  -1 * (eLineFlow_PDL_ub - vLineFlow) = {(-1 * (eLineFlow_PDL_ub - vLineFlow)).tolist()}\n"
    f"  eLineFlow_LP_ub = {eLineFlow_LP_ub.tolist()}"
)

print("Testing consistency of eRampingDown")
eRampingDown_idx = eLineFlow_idx_ub + len(G) * (12-1)
eRampingDown_PDL = g[eLineFlow_idx_ub:eRampingDown_idx]
eRampingDown_LP = get_constraint_values_as_list(model.eRampingDown)

assert np.allclose(np.array(eRampingDown_PDL), np.array(eRampingDown_LP), atol=1e-10)

print("Testing consistency of eRampingUp")
eRampingUp_idx = eRampingDown_idx + len(G) * (12-1)
eRampingUp_PDL = g[eRampingDown_idx:eRampingUp_idx]
eRampingUp_LP = get_constraint_values_as_list(model.eRampingUp)

assert np.allclose(np.array(eRampingUp_PDL), np.array(eRampingUp_LP), atol=1e-10)

print("Testing consistency of eGenProdPositive")
eGenProdPositive_idx = eRampingUp_idx + len(G) * 12
eGenProdPositive_PDL = g[eRampingUp_idx:eGenProdPositive_idx]

vGenProd = get_variable_values_as_list(model.vGenProd)

assert np.allclose(np.array(eGenProdPositive_PDL), -1*np.array(vGenProd), atol=1e-10)

print("Testing consistency of eMissedDemandPositive")
eMissedDemandPositive_idx = eGenProdPositive_idx + len(N) * 12
eMissedDemandPositive_PDL = g[eGenProdPositive_idx:eMissedDemandPositive_idx]

vLossLoad = get_variable_values_as_list(model.vLossLoad)

assert np.allclose(np.array(eMissedDemandPositive_PDL), -1*np.array(vLossLoad), atol=1e-10)

print("Testing consistency of eMissedDemandLeqDemand")
eMissedDemandLeqDemand_idx = eMissedDemandPositive_idx + len(N) * 12
eMissedDemandLeqDemand_PDL = g[eMissedDemandPositive_idx:eMissedDemandLeqDemand_idx]

vLossLoad = get_variable_values_as_list(model.vLossLoad)
pDemand = data.pDemand_tensor[:, :12].flatten().tolist()

assert np.allclose(np.array(eMissedDemandLeqDemand_PDL), np.array(vLossLoad) - np.array(pDemand), atol=1e-10)

print("Testing consistency of eNumPowerGenerationUnitsPositive")
eNumPowerGenerationUnitsPositive_idx = eMissedDemandLeqDemand_idx + len(G)
eNumPowerGenerationUnitsPositive_PDL = g[eMissedDemandLeqDemand_idx:eNumPowerGenerationUnitsPositive_idx]


vGenInv = get_variable_values_as_list(model.vGenInv)

assert np.allclose(np.array(eNumPowerGenerationUnitsPositive_PDL), -1*np.array(vGenInv), atol=1e-10)
# Out:
# ### Testing constistency of g_x(y) ###
# Testing consistency of eMaxProd
# Testing consistency of eLineFlow
# Testing consistency of eRampingDown
# Testing consistency of eRampingUp
# Testing consistency of eGenProdPositive
# Testing consistency of eMissedDemandPositive
# Testing consistency of eMissedDemandLeqDemand
# Testing consistency of eNumPowerGenerationUnitsPositive

# %%
h = data.h(X, Y).squeeze(0).tolist()

# %%
print("### Testing consistency of h_x(y) ###")
# h returns eNodeBal

print("Testing consistency of eNodeBal")
eNodeBal_PDL = h
eNodeBal_LP = get_constraint_values_as_list(model.eNodeBal)

assert np.allclose(np.array(eNodeBal_PDL), np.array(eNodeBal_LP) - np.array(pDemand), atol=1e-10)
# Out:
# ### Testing consistency of h_x(y) ###
# Testing consistency of eNodeBal

# %%
print("### Testing consistency of f_x(y)")

obj_LP = model.obj()

obj_PDL = data.obj_fn(Y)

assert obj_LP == obj_PDL

print(obj_LP)
print(obj_PDL)
# Out:
# ### Testing consistency of f_x(y)
# torch.Size([1, 111])
# 818648032.282804
# tensor([8.1865e+08])
